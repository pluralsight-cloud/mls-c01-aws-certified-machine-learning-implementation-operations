# %% [markdown]
# # Amazon SageMaker Batch Transform Demo

# %% [markdown]
# _**Use SageMaker's XGBoost to train a binary classification model and for a list of tumors in batch file, predict if each is malignant**_
#
# ## Setup
#
# After installing the Sagemaker Python SDK
# specify:
#
# * The SageMaker role arn which has the SageMakerFullAccess policy attached
# * The S3 bucket to use for training and storing model objects.

# %%
# !pip3 install -U sagemaker
# Out:
# Requirement already satisfied: sagemaker in /opt/conda/lib/python3.10/site-packages (2.224.1)
# Collecting sagemaker
#   Downloading sagemaker-2.226.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: attrs<24,>=23.1.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker) (23.2.0)
# Collecting boto3<2.0,>=1.34.142 (from sagemaker)
#   Downloading boto3-1.34.149-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: cloudpickle==2.2.1 in /opt/conda/lib/python3.10/site-packages (from sagemaker) (2.2.1)
# Requirement already satisfied: google-pasta in /opt/conda/lib/python3.10/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker) (1.26.4)
# Requirement already satisfied: protobuf<5.0,>=3.12 in /opt/conda/lib/python3.10/site-packages (from sagemaker) (4.24.4)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /opt/conda/lib/python3.10/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker) (6.10.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker) (23.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from sagemaker) (2.1.4)
# Requirement already satisfied: pathos in /opt/conda/lib/python3.10/site-packages (from sagemaker) (0.3.2)
# Requirement already satisfied: schema in /opt/conda/lib/python3.10/site-packages (from sagemaker) (0.7.7)
# Requirement already satisfied: PyYAML~=6.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker) (6.0.1)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from sagemaker) (4.17.3)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from sagemaker) (4.2.2)
# Requirement already satisfied: tblib<4,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker) (2.0.0)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in /opt/conda/lib/python3.10/site-packages (from sagemaker) (1.26.19)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from sagemaker) (2.32.3)
# Requirement already satisfied: docker in /opt/conda/lib/python3.10/site-packages (from sagemaker) (7.1.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sagemaker) (4.66.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from sagemaker) (5.9.8)
# Collecting botocore<1.35.0,>=1.34.149 (from boto3<2.0,>=1.34.142->sagemaker)
#   Downloading botocore-1.34.149-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3<2.0,>=1.34.142->sagemaker) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from boto3<2.0,>=1.34.142->sagemaker) (0.10.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->sagemaker) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->sagemaker) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->sagemaker) (2024.6.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from google-pasta->sagemaker) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->sagemaker) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->sagemaker) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->sagemaker) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->sagemaker) (2024.1)
# Requirement already satisfied: ppft>=1.7.6.8 in /opt/conda/lib/python3.10/site-packages (from pathos->sagemaker) (1.7.6.8)
# Requirement already satisfied: dill>=0.3.8 in /opt/conda/lib/python3.10/site-packages (from pathos->sagemaker) (0.3.8)
# Requirement already satisfied: pox>=0.3.4 in /opt/conda/lib/python3.10/site-packages (from pathos->sagemaker) (0.3.4)
# Requirement already satisfied: multiprocess>=0.70.16 in /opt/conda/lib/python3.10/site-packages (from pathos->sagemaker) (0.70.16)
# Downloading sagemaker-2.226.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 46.0 MB/s eta 0:00:00
# Downloading boto3-1.34.149-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 17.8 MB/s eta 0:00:00
# Downloading botocore-1.34.149-py3-none-any.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 78.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: botocore, boto3, sagemaker
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.131
#     Uninstalling botocore-1.34.131:
#       Successfully uninstalled botocore-1.34.131
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.34.131
#     Uninstalling boto3-1.34.131:
#       Successfully uninstalled boto3-1.34.131
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.224.1
#     Uninstalling sagemaker-2.224.1:
#       Successfully uninstalled sagemaker-2.224.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.13.1 requires botocore<1.34.132,>=1.34.70, but you have botocore 1.34.149 which is incompatible.
# autogluon-common 0.8.3 requires pandas<1.6,>=1.4.1, but you have pandas 2.1.4 which is incompatible.
# autogluon-core 0.8.3 requires pandas<1.6,>=1.4.1, but you have pandas 2.1.4 which is incompatible.
# autogluon-core 0.8.3 requires scikit-learn<1.4.1,>=1.1, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-features 0.8.3 requires pandas<1.6,>=1.4.1, but you have pandas 2.1.4 which is incompatible.
# autogluon-features 0.8.3 requires scikit-learn<1.4.1,>=1.1, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 0.8.3 requires pandas<1.6,>=1.4.1, but you have pandas 2.1.4 which is incompatible.
# autogluon-multimodal 0.8.3 requires pytorch-lightning<1.10.0,>=1.9.0, but you have pytorch-lightning 2.0.9 which is incompatible.
# autogluon-multimodal 0.8.3 requires scikit-learn<1.4.1,>=1.1, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 0.8.3 requires torch<1.14,>=1.9, but you have torch 2.0.0.post104 which is incompatible.
# autogluon-multimodal 0.8.3 requires torchmetrics<0.12.0,>=0.11.0, but you have torchmetrics 1.0.3 which is incompatible.
# autogluon-multimodal 0.8.3 requires torchvision<0.15.0, but you have torchvision 0.15.2a0+ab7b3e6 which is incompatible.
# autogluon-tabular 0.8.3 requires pandas<1.6,>=1.4.1, but you have pandas 2.1.4 which is incompatible.
# autogluon-tabular 0.8.3 requires scikit-learn<1.4.1,>=1.1, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-timeseries 0.8.3 requires pandas<1.6,>=1.4.1, but you have pandas 2.1.4 which is incompatible.
# autogluon-timeseries 0.8.3 requires pytorch-lightning<1.10.0,>=1.7.4, but you have pytorch-lightning 2.0.9 which is incompatible.
# autogluon-timeseries 0.8.3 requires torch<1.14,>=1.9, but you have torch 2.0.0.post104 which is incompatible.
# Successfully installed boto3-1.34.149 botocore-1.34.149 sagemaker-2.226.1

# %%
import os
import boto3
import sagemaker

role = sagemaker.get_execution_role()
sess = sagemaker.Session()
region = sess.boto_region_name

bucket = sess.default_bucket()
prefix = "DEMO-breast-cancer-prediction-xgboost-highlevel"

# %% [markdown]
# ---
# ## Data sources
#
# > Dua, D. and Graff, C. (2019). UCI Machine Learning Repository [http://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science.
#
# ## Data preparation
#
# Download the data and save it in a local folder with the name data.csv

# %%
import pandas as pd
import numpy as np

s3 = boto3.client("s3")

filename = "wdbc.csv"
s3.download_file(
    f"sagemaker-example-files-prod-{region}", "datasets/tabular/breast_cancer/wdbc.csv", filename
)
data = pd.read_csv(filename, header=None)

# specify columns extracted from wbdc.names
data.columns = [
    "id",
    "diagnosis",
    "radius_mean",
    "texture_mean",
    "perimeter_mean",
    "area_mean",
    "smoothness_mean",
    "compactness_mean",
    "concavity_mean",
    "concave points_mean",
    "symmetry_mean",
    "fractal_dimension_mean",
    "radius_se",
    "texture_se",
    "perimeter_se",
    "area_se",
    "smoothness_se",
    "compactness_se",
    "concavity_se",
    "concave points_se",
    "symmetry_se",
    "fractal_dimension_se",
    "radius_worst",
    "texture_worst",
    "perimeter_worst",
    "area_worst",
    "smoothness_worst",
    "compactness_worst",
    "concavity_worst",
    "concave points_worst",
    "symmetry_worst",
    "fractal_dimension_worst",
]

# save the data
data.to_csv("data.csv", sep=",", index=False)

data.sample(8)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 216   8811523         B        11.89         18.35           77.32      432.2
# 447   9110944         B        14.80         17.66           95.88      674.8
# 432    908194         M        20.18         19.54          133.80     1250.0
# 144    869254         B        10.75         14.97           68.26      355.3
# 224   8813129         B        13.27         17.02           84.55      546.4
# 411    905520         B        11.04         16.83           70.92      373.2
# 442  90944601         B        13.78         15.79           88.37      585.9
# 207    879830         M        17.01         20.26          109.70      904.3
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 216          0.09363           0.11540         0.06636             0.031420
# 447          0.09179           0.08890         0.04069             0.022600
# 432          0.11330           0.14890         0.21330             0.125900
# 144          0.07793           0.05139         0.02251             0.007875
# 224          0.08445           0.04994         0.03554             0.024560
# 411          0.10770           0.07804         0.03046             0.024800
# 442          0.08817           0.06718         0.01055             0.009937
# 207          0.08772           0.07304         0.06950             0.053900
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 216  ...         13.25          27.10            86.20       531.2
# 447  ...         16.43          22.74           105.90       829.5
# 432  ...         22.03          25.07           146.00      1479.0
# 144  ...         11.95          20.72            77.79       441.2
# 224  ...         15.14          23.60            98.84       708.8
# 411  ...         12.41          26.44            79.93       471.4
# 442  ...         15.27          17.50            97.90       706.6
# 207  ...         19.80          25.05           130.00      1210.0
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 216            0.1405             0.3046          0.28060
# 447            0.1226             0.1881          0.20600
# 432            0.1665             0.2942          0.53080
# 144            0.1076             0.1223          0.09755
# 224            0.1276             0.1311          0.17860
# 411            0.1369             0.1482          0.10670
# 442            0.1072             0.1071          0.03517
# 207            0.1111             0.1486          0.19320
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 216               0.11380          0.3397                  0.08365
# 447               0.08308          0.3600                  0.07285
# 432               0.21730          0.3032                  0.08075
# 144               0.03413          0.2300                  0.06769
# 224               0.09678          0.2506                  0.07623
# 411               0.07431          0.2998                  0.07881
# 442               0.03312          0.1859                  0.06810
# 207               0.10960          0.3275                  0.06469
#
# [8 rows x 32 columns]

# %% [markdown]
# #### Note:
# * The first field is an 'id' attribute that we'll remove before batch inference since it is not useful for inference
# * The second field, 'diagnosis', uses 'M' for Malignant and 'B'for Benign.
# * There are 30 other numeric features that will be use for training and inferenc.

# %% [markdown]
# Let's replace the M/B diagnosis with a 1/0 boolean value.

# %%
data["diagnosis"] = data["diagnosis"].apply(lambda x: ((x == "M")) + 0)
data.sample(8)
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 361    901041          0       13.300         21.57           85.24
# 508    915452          0       16.300         15.70          104.70
# 65     859283          1       14.780         23.94           97.40
# 504    915186          0        9.268         12.87           61.49
# 488    913512          0       11.680         16.17           75.49
# 259  88725602          1       15.530         33.56          103.70
# 326     89524          0       14.110         12.88           90.03
# 418    906024          0       12.700         12.17           80.88
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 361      546.1          0.08582           0.06373         0.03344
# 508      819.8          0.09427           0.06712         0.05526
# 65       668.3          0.11720           0.14790         0.12670
# 504      248.7          0.16340           0.22390         0.09730
# 488      420.5          0.11280           0.09263         0.04279
# 259      744.9          0.10630           0.16390         0.17510
# 326      616.5          0.09309           0.05306         0.01765
# 418      495.0          0.08785           0.05794         0.02360
#
#      concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 361              0.02424  ...         14.20          29.20            92.94
# 508              0.04563  ...         17.32          17.76           109.80
# 65               0.09029  ...         17.31          33.39           114.60
# 504              0.05252  ...         10.28          16.38            69.05
# 488              0.03132  ...         13.32          21.59            86.57
# 259              0.08399  ...         18.49          49.54           126.30
# 326              0.02733  ...         15.53          18.00            98.40
# 418              0.02402  ...         13.65          16.92            88.12
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 361       621.2            0.1140             0.1667          0.12120
# 508       928.2            0.1354             0.1361          0.19470
# 65        925.1            0.1648             0.3416          0.30240
# 504       300.2            0.1902             0.3441          0.20990
# 488       549.8            0.1526             0.1477          0.14900
# 259      1035.0            0.1883             0.5564          0.57030
# 326       749.9            0.1281             0.1109          0.05307
# 418       566.9            0.1314             0.1607          0.09385
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 361               0.05614          0.2637                  0.06658
# 508               0.13570          0.2300                  0.07230
# 65                0.16140          0.3321                  0.08911
# 504               0.10250          0.3038                  0.12520
# 488               0.09815          0.2804                  0.08024
# 259               0.20140          0.3512                  0.12040
# 326               0.05890          0.2100                  0.07083
# 418               0.08224          0.2775                  0.09464
#
# [8 rows x 32 columns]

# %% [markdown]
# Split the data as follows:
# 80% for training
# 10% for validation
# 10% for batch inference job
#
# In addition, let's remove the 'id' field on the training set and validation set as 'id' is not a training feature.
# Remove the diagnosis attribute for the batch set because this is what we want to predict.

# %%
# data split in three sets, training, validation and batch inference
rand_split = np.random.rand(len(data))
train_list = rand_split < 0.8
val_list = (rand_split >= 0.8) & (rand_split < 0.9)
batch_list = rand_split >= 0.9

data_train = data[train_list].drop(["id"], axis=1)
data_val = data[val_list].drop(["id"], axis=1)
data_batch = data[batch_list].drop(["diagnosis"], axis=1)
data_batch_noID = data_batch.drop(["id"], axis=1)

# %% [markdown]
# Upload the data sets to S3

# %%
train_file = "train_data.csv"
data_train.to_csv(train_file, index=False, header=False)
sess.upload_data(train_file, key_prefix="{}/train".format(prefix))

validation_file = "validation_data.csv"
data_val.to_csv(validation_file, index=False, header=False)
sess.upload_data(validation_file, key_prefix="{}/validation".format(prefix))

batch_file = "batch_data.csv"
data_batch.to_csv(batch_file, index=False, header=False)
sess.upload_data(batch_file, key_prefix="{}/batch".format(prefix))

batch_file_noID = "batch_data_noID.csv"
data_batch_noID.to_csv(batch_file_noID, index=False, header=False)
sess.upload_data(batch_file_noID, key_prefix="{}/batch".format(prefix))
# Out:
# 's3://sagemaker-us-east-1-548734566896/DEMO-breast-cancer-prediction-xgboost-highlevel/batch/batch_data_noID.csv'

# %% [markdown]
# ---
#
# ## Training job and model creation

# %% [markdown]
# Start the training job using both training set and validation set.
#
# The model will output a probability between 0 and 1 which is predicting the probability of a tumor being malignant.

# %%
# %%time
from time import gmtime, strftime

job_name = "xgb-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())
output_location = "s3://{}/{}/output/{}".format(bucket, prefix, job_name)
image = sagemaker.image_uris.retrieve(
    framework="xgboost", region=boto3.Session().region_name, version="1.7-1"
)

sm_estimator = sagemaker.estimator.Estimator(
    image,
    role,
    instance_count=1,
    instance_type="ml.m5.large",
    volume_size=50,
    input_mode="File",
    output_path=output_location,
    sagemaker_session=sess,
)

sm_estimator.set_hyperparameters(
    objective="binary:logistic",
    max_depth=5,
    eta=0.2,
    gamma=4,
    min_child_weight=6,
    subsample=0.8,
    verbosity=0,
    num_round=100,
)

train_data = sagemaker.inputs.TrainingInput(
    "s3://{}/{}/train".format(bucket, prefix),
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
)
validation_data = sagemaker.inputs.TrainingInput(
    "s3://{}/{}/validation".format(bucket, prefix),
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
)
data_channels = {"train": train_data, "validation": validation_data}

# Start training by calling the fit method in the estimator
sm_estimator.fit(inputs=data_channels, logs=True)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2024-07-27-14-13-30-936
# 2024-07-27 14:13:31 Starting - Starting the training job...
# 2024-07-27 14:13:46 Starting - Preparing the instances for training...
# 2024-07-27 14:14:17 Downloading - Downloading input data......
# 2024-07-27 14:15:08 Downloading - Downloading the training image......
# 2024-07-27 14:16:24 Training - Training image download completed. Training in progress.
# 2024-07-27 14:16:24 Uploading - Uploading generated training model[2024-07-27 14:16:17.337 ip-10-0-105-4.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-07-27 14:16:17.369 ip-10-0-105-4.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-07-27:14:16:17:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-07-27:14:16:17:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-07-27:14:16:17:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:16:18:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-07-27:14:16:18:INFO] Determined 0 GPU(s) available on the instance.
# [2024-07-27:14:16:18:INFO] Determined delimiter of CSV input is ','
# [2024-07-27:14:16:18:INFO] Determined delimiter of CSV input is ','
# [2024-07-27:14:16:18:INFO] File path /opt/ml/input/data/train of input files
# [2024-07-27:14:16:18:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-07-27:14:16:18:INFO] creating symlink between Path /opt/ml/input/data/train/train_data.csv and destination /tmp/sagemaker_xgboost_input_data/train_data.csv8902034540056451579
# [2024-07-27:14:16:18:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-07-27:14:16:18:INFO] Determined delimiter of CSV input is ','
# [2024-07-27:14:16:18:INFO] File path /opt/ml/input/data/validation of input files
# [2024-07-27:14:16:18:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-07-27:14:16:18:INFO] creating symlink between Path /opt/ml/input/data/validation/validation_data.csv and destination /tmp/sagemaker_xgboost_input_data/validation_data.csv4439593057640315119
# [2024-07-27:14:16:18:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-07-27:14:16:18:INFO] Determined delimiter of CSV input is ','
# [2024-07-27:14:16:18:INFO] Single node training.
# [2024-07-27:14:16:18:INFO] Train matrix has 444 rows and 30 columns
# [2024-07-27:14:16:18:INFO] Validation matrix has 70 rows
# [2024-07-27 14:16:18.068 ip-10-0-105-4.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2024-07-27 14:16:18.069 ip-10-0-105-4.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2024-07-27 14:16:18.070 ip-10-0-105-4.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2024-07-27 14:16:18.070 ip-10-0-105-4.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2024-07-27:14:16:18:INFO] Debug hook created from config
# [2024-07-27 14:16:18.172 ip-10-0-105-4.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2024-07-27 14:16:18.176 ip-10-0-105-4.ec2.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [0]#011train-logloss:0.54732#011validation-logloss:0.55054
# [1]#011train-logloss:0.44955#011validation-logloss:0.45583
# [2]#011train-logloss:0.37587#011validation-logloss:0.37964
# [3]#011train-logloss:0.32344#011validation-logloss:0.32676
# [4]#011train-logloss:0.27994#011validation-logloss:0.28001
# [5]#011train-logloss:0.24797#011validation-logloss:0.25054
# [6]#011train-logloss:0.22044#011validation-logloss:0.22364
# [7]#011train-logloss:0.19911#011validation-logloss:0.20191
# [8]#011train-logloss:0.17966#011validation-logloss:0.18138
# [9]#011train-logloss:0.16363#011validation-logloss:0.16363
# [10]#011train-logloss:0.15035#011validation-logloss:0.15288
# [11]#011train-logloss:0.13930#011validation-logloss:0.14152
# [12]#011train-logloss:0.12971#011validation-logloss:0.13252
# [13]#011train-logloss:0.12464#011validation-logloss:0.12355
# [14]#011train-logloss:0.11602#011validation-logloss:0.11896
# [15]#011train-logloss:0.11031#011validation-logloss:0.11362
# [16]#011train-logloss:0.10467#011validation-logloss:0.10755
# [17]#011train-logloss:0.09910#011validation-logloss:0.10302
# [18]#011train-logloss:0.09696#011validation-logloss:0.10110
# [19]#011train-logloss:0.09519#011validation-logloss:0.10157
# [20]#011train-logloss:0.09290#011validation-logloss:0.09936
# [21]#011train-logloss:0.09052#011validation-logloss:0.09792
# [22]#011train-logloss:0.09052#011validation-logloss:0.09803
# [23]#011train-logloss:0.08860#011validation-logloss:0.09489
# [24]#011train-logloss:0.08860#011validation-logloss:0.09469
# [25]#011train-logloss:0.08859#011validation-logloss:0.09429
# [26]#011train-logloss:0.08858#011validation-logloss:0.09404
# [27]#011train-logloss:0.08858#011validation-logloss:0.09375
# [28]#011train-logloss:0.08857#011validation-logloss:0.09295
# [29]#011train-logloss:0.08858#011validation-logloss:0.09242
# [30]#011train-logloss:0.08688#011validation-logloss:0.09153
# [31]#011train-logloss:0.08687#011validation-logloss:0.09204
# [32]#011train-logloss:0.08687#011validation-logloss:0.09172
# [33]#011train-logloss:0.08688#011validation-logloss:0.09252
# [34]#011train-logloss:0.08688#011validation-logloss:0.09269
# [35]#011train-logloss:0.08689#011validation-logloss:0.09302
# [36]#011train-logloss:0.08689#011validation-logloss:0.09304
# [37]#011train-logloss:0.08690#011validation-logloss:0.09342
# [38]#011train-logloss:0.08689#011validation-logloss:0.09306
# [39]#011train-logloss:0.08689#011validation-logloss:0.09295
# [40]#011train-logloss:0.08570#011validation-logloss:0.09206
# [41]#011train-logloss:0.08570#011validation-logloss:0.09198
# [42]#011train-logloss:0.08382#011validation-logloss:0.08844
# [43]#011train-logloss:0.08382#011validation-logloss:0.08853
# [44]#011train-logloss:0.08382#011validation-logloss:0.08823
# [45]#011train-logloss:0.08381#011validation-logloss:0.08904
# [46]#011train-logloss:0.08382#011validation-logloss:0.08798
# [47]#011train-logloss:0.08384#011validation-logloss:0.08741
# [48]#011train-logloss:0.08382#011validation-logloss:0.08797
# [49]#011train-logloss:0.08381#011validation-logloss:0.08919
# [50]#011train-logloss:0.08381#011validation-logloss:0.08885
# [51]#011train-logloss:0.08381#011validation-logloss:0.08931
# [52]#011train-logloss:0.08381#011validation-logloss:0.08898
# [53]#011train-logloss:0.08382#011validation-logloss:0.08846
# [54]#011train-logloss:0.08382#011validation-logloss:0.08852
# [55]#011train-logloss:0.08382#011validation-logloss:0.08960
# [56]#011train-logloss:0.08382#011validation-logloss:0.08943
# [57]#011train-logloss:0.08250#011validation-logloss:0.08905
# [58]#011train-logloss:0.08251#011validation-logloss:0.08947
# [59]#011train-logloss:0.08252#011validation-logloss:0.09030
# [60]#011train-logloss:0.08255#011validation-logloss:0.09098
# [61]#011train-logloss:0.08252#011validation-logloss:0.09009
# [62]#011train-logloss:0.08253#011validation-logloss:0.09051
# [63]#011train-logloss:0.08257#011validation-logloss:0.09143
# [64]#011train-logloss:0.08259#011validation-logloss:0.09186
# [65]#011train-logloss:0.08254#011validation-logloss:0.09094
# [66]#011train-logloss:0.08252#011validation-logloss:0.09034
# [67]#011train-logloss:0.08151#011validation-logloss:0.08988
# [68]#011train-logloss:0.08152#011validation-logloss:0.09038
# [69]#011train-logloss:0.08151#011validation-logloss:0.09024
# [70]#011train-logloss:0.08155#011validation-logloss:0.09190
# [71]#011train-logloss:0.08153#011validation-logloss:0.09120
# [72]#011train-logloss:0.08152#011validation-logloss:0.09084
# [73]#011train-logloss:0.08151#011validation-logloss:0.09002
# [74]#011train-logloss:0.08151#011validation-logloss:0.09021
# [75]#011train-logloss:0.08151#011validation-logloss:0.08931
# [76]#011train-logloss:0.08151#011validation-logloss:0.08982
# [77]#011train-logloss:0.08152#011validation-logloss:0.09054
# [78]#011train-logloss:0.08152#011validation-logloss:0.08902
# [79]#011train-logloss:0.08152#011validation-logloss:0.08857
# [80]#011train-logloss:0.08152#011validation-logloss:0.08906
# [81]#011train-logloss:0.08151#011validation-logloss:0.08971
# [82]#011train-logloss:0.08152#011validation-logloss:0.08873
# [83]#011train-logloss:0.08152#011validation-logloss:0.08859
# [84]#011train-logloss:0.08152#011validation-logloss:0.08911
# [85]#011train-logloss:0.08152#011validation-logloss:0.08897
# [86]#011train-logloss:0.08151#011validation-logloss:0.08954
# [87]#011train-logloss:0.08151#011validation-logloss:0.09005
# [88]#011train-logloss:0.08151#011validation-logloss:0.09006
# [89]#011train-logloss:0.08152#011validation-logloss:0.08908
# [90]#011train-logloss:0.08152#011validation-logloss:0.08864
# [91]#011train-logloss:0.08152#011validation-logloss:0.08889
# [92]#011train-logloss:0.08153#011validation-logloss:0.08844
# [93]#011train-logloss:0.08152#011validation-logloss:0.08882
# [94]#011train-logloss:0.08157#011validation-logloss:0.08724
# [95]#011train-logloss:0.08156#011validation-logloss:0.08745
# [96]#011train-logloss:0.07999#011validation-logloss:0.08496
# [97]#011train-logloss:0.07998#011validation-logloss:0.08524
# [98]#011train-logloss:0.07999#011validation-logloss:0.08517
# [99]#011train-logloss:0.07998#011validation-logloss:0.08538
#
# 2024-07-27 14:16:37 Completed - Training job completed
# Training seconds: 140
# Billable seconds: 140
# CPU times: user 566 ms, sys: 45.9 ms, total: 612 ms
# Wall time: 3min 42s

# %% [markdown]
# ---
#
# ## Batch Transform
# Instead of deploying an endpoint and running real-time inference, we'll use SageMaker Batch Transform to run inference on an entire data set in one operation.

# %% [markdown]
# #### 1. Create a transform job

# %%
# %%time

sm_transformer = sm_estimator.transformer(1, "ml.m5.large")

# start a transform job
input_location = "s3://{}/{}/batch/{}".format(
    bucket, prefix, batch_file_noID
)  # use input data without ID column
sm_transformer.transform(input_location, content_type="text/csv", split_type="Line")
sm_transformer.wait()
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2024-07-27-14-20-52-044
# INFO:sagemaker:Creating transform job with name: sagemaker-xgboost-2024-07-27-14-20-52-811
# ...................................[2024-07-27:14:26:46:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:26:46:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:26:46:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2024-07-27 14:26:46 +0000] [14] [INFO] Starting gunicorn 19.10.0
# [2024-07-27 14:26:46 +0000] [14] [INFO] Listening at: unix:/tmp/gunicorn.sock (14)
# [2024-07-27 14:26:46 +0000] [14] [INFO] Using worker: gevent
# /miniconda3/lib/python3.8/os.py:1023: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   return io.open(fd, *args, **kwargs)
# [2024-07-27 14:26:46 +0000] [18] [INFO] Booting worker with pid: 18
# [2024-07-27 14:26:46 +0000] [19] [INFO] Booting worker with pid: 19
# [2024-07-27:14:26:48:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:26:48:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2024-07-27:14:26:48:INFO] Model objective : binary:logistic
# [2024-07-27:14:26:48:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:26:48:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2024-07-27:14:26:48:INFO] Model objective : binary:logistic
#
# [2024-07-27:14:26:55:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:26:55 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2024-07-27:14:26:55:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:26:55 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2024-07-27:14:26:55:INFO] Determined delimiter of CSV input is ','
# /miniconda3/lib/python3.8/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# 169.254.255.130 - - [27/Jul/2024:14:26:55 +0000] "POST /invocations HTTP/1.1" 200 1089 "-" "Go-http-client/1.1"
# [2024-07-27:14:26:55:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:26:55 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2024-07-27:14:26:55:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:26:55 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2024-07-27:14:26:55:INFO] Determined delimiter of CSV input is ','
# /miniconda3/lib/python3.8/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# 169.254.255.130 - - [27/Jul/2024:14:26:55 +0000] "POST /invocations HTTP/1.1" 200 1089 "-" "Go-http-client/1.1"
# 2024-07-27T14:26:55.492:[sagemaker logs]: MaxConcurrentTransforms=2, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2024-07-27:14:26:46:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:26:46:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:26:46:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2024-07-27:14:26:46:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:26:46:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:26:46:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2024-07-27 14:26:46 +0000] [14] [INFO] Starting gunicorn 19.10.0
# [2024-07-27 14:26:46 +0000] [14] [INFO] Listening at: unix:/tmp/gunicorn.sock (14)
# [2024-07-27 14:26:46 +0000] [14] [INFO] Using worker: gevent
# /miniconda3/lib/python3.8/os.py:1023: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   return io.open(fd, *args, **kwargs)
# [2024-07-27 14:26:46 +0000] [18] [INFO] Booting worker with pid: 18
# [2024-07-27 14:26:46 +0000] [19] [INFO] Booting worker with pid: 19
# [2024-07-27:14:26:48:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:26:48:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2024-07-27:14:26:48:INFO] Model objective : binary:logistic
# [2024-07-27:14:26:48:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:26:48:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2024-07-27:14:26:48:INFO] Model objective : binary:logistic
# [2024-07-27 14:26:46 +0000] [14] [INFO] Starting gunicorn 19.10.0
# [2024-07-27 14:26:46 +0000] [14] [INFO] Listening at: unix:/tmp/gunicorn.sock (14)
# [2024-07-27 14:26:46 +0000] [14] [INFO] Using worker: gevent
# /miniconda3/lib/python3.8/os.py:1023: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   return io.open(fd, *args, **kwargs)
# [2024-07-27 14:26:46 +0000] [18] [INFO] Booting worker with pid: 18
# [2024-07-27 14:26:46 +0000] [19] [INFO] Booting worker with pid: 19
# [2024-07-27:14:26:48:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:26:48:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2024-07-27:14:26:48:INFO] Model objective : binary:logistic
# [2024-07-27:14:26:48:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:26:48:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2024-07-27:14:26:48:INFO] Model objective : binary:logistic
# [2024-07-27:14:26:55:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:26:55 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2024-07-27:14:26:55:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:26:55 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2024-07-27:14:26:55:INFO] Determined delimiter of CSV input is ','
# /miniconda3/lib/python3.8/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# 169.254.255.130 - - [27/Jul/2024:14:26:55 +0000] "POST /invocations HTTP/1.1" 200 1089 "-" "Go-http-client/1.1"
# [2024-07-27:14:26:55:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:26:55 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2024-07-27:14:26:55:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:26:55 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2024-07-27:14:26:55:INFO] Determined delimiter of CSV input is ','
# /miniconda3/lib/python3.8/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# 169.254.255.130 - - [27/Jul/2024:14:26:55 +0000] "POST /invocations HTTP/1.1" 200 1089 "-" "Go-http-client/1.1"
# 2024-07-27T14:26:55.492:[sagemaker logs]: MaxConcurrentTransforms=2, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# CPU times: user 1.03 s, sys: 30.7 ms, total: 1.06 s
# Wall time: 6min 35s

# %% [markdown]
# Check the output of the Batch Transform job. It should show the list of probabilities of tumors being malignant.

# %%
import re


def get_csv_output_from_s3(s3uri, batch_file):
    file_name = "{}.out".format(batch_file)
    match = re.match("s3://([^/]+)/(.*)", "{}/{}".format(s3uri, file_name))
    output_bucket, output_prefix = match.group(1), match.group(2)
    s3.download_file(output_bucket, output_prefix, file_name)
    return pd.read_csv(file_name, sep=",", header=None)

# %%
output_df = get_csv_output_from_s3(sm_transformer.output_path, batch_file_noID)
output_df.head(8)
# Out:
#           0
# 0  0.788581
# 1  0.992829
# 2  0.990109
# 3  0.989060
# 4  0.098793
# 5  0.039862
# 6  0.985368
# 7  0.523357

# %% [markdown]
# #### 2. Join the input and the prediction results
# Now, let's associate the prediction results with their corresponding input records. We can also use the __input_filter__ to exclude the ID column easily and there's no need to have a separate file in S3.
#
# * Set __input_filter__ to "$[1:]": indicates that we are excluding column 0 (the 'ID') before processing the inferences and keeping everything from column 1 to the last column (all the features or predictors)
#
#
# * Set __join_source__ to "Input": indicates our desire to join the input data with the inference results
#
# * Set __output_filter__ to default "$[1:]", indicating that when presenting the output, we only want to keep column 0 (the 'ID') and the last column (the inference result)

# %%
# content_type / accept and split_type / assemble_with are required to use IO joining feature
sm_transformer.assemble_with = "Line"
sm_transformer.accept = "text/csv"

# start a transform job
input_location = "s3://{}/{}/batch/{}".format(
    bucket, prefix, batch_file
)  # use input data with ID column cause InputFilter will filter it out
sm_transformer.transform(
    input_location,
    split_type="Line",
    content_type="text/csv",
    input_filter="$[1:]",
    join_source="Input",
    output_filter="$[0,-1]",
)
sm_transformer.wait()
# Out:
# INFO:sagemaker:Creating transform job with name: sagemaker-xgboost-2024-07-27-14-28-01-439
# ...............................[2024-07-27:14:33:10:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:33:10:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:33:10:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2024-07-27 14:33:10 +0000] [15] [INFO] Starting gunicorn 19.10.0
# [2024-07-27 14:33:10 +0000] [15] [INFO] Listening at: unix:/tmp/gunicorn.sock (15)
# [2024-07-27 14:33:10 +0000] [15] [INFO] Using worker: gevent
# /miniconda3/lib/python3.8/os.py:1023: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   return io.open(fd, *args, **kwargs)
# [2024-07-27 14:33:10 +0000] [19] [INFO] Booting worker with pid: 19
# [2024-07-27 14:33:10 +0000] [20] [INFO] Booting worker with pid: 20
# [2024-07-27:14:33:12:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:33:12:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2024-07-27:14:33:12:INFO] Model objective : binary:logistic
# [2024-07-27:14:33:12:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:33:12:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2024-07-27:14:33:12:INFO] Model objective : binary:logistic
# [2024-07-27:14:33:19:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:33:19 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2024-07-27:14:33:19:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:33:19 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2024-07-27:14:33:19:INFO] Determined delimiter of CSV input is ','
# /miniconda3/lib/python3.8/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# 169.254.255.130 - - [27/Jul/2024:14:33:19 +0000] "POST /invocations HTTP/1.1" 200 1089 "-" "Go-http-client/1.1"
# [2024-07-27:14:33:19:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:33:19 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2024-07-27:14:33:19:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:33:19 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2024-07-27:14:33:19:INFO] Determined delimiter of CSV input is ','
# /miniconda3/lib/python3.8/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# 169.254.255.130 - - [27/Jul/2024:14:33:19 +0000] "POST /invocations HTTP/1.1" 200 1089 "-" "Go-http-client/1.1"
# 2024-07-27T14:33:19.071:[sagemaker logs]: MaxConcurrentTransforms=2, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
#
# [2024-07-27:14:33:10:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:33:10:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:33:10:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2024-07-27:14:33:10:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:33:10:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:33:10:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2024-07-27 14:33:10 +0000] [15] [INFO] Starting gunicorn 19.10.0
# [2024-07-27 14:33:10 +0000] [15] [INFO] Listening at: unix:/tmp/gunicorn.sock (15)
# [2024-07-27 14:33:10 +0000] [15] [INFO] Using worker: gevent
# /miniconda3/lib/python3.8/os.py:1023: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   return io.open(fd, *args, **kwargs)
# [2024-07-27 14:33:10 +0000] [19] [INFO] Booting worker with pid: 19
# [2024-07-27 14:33:10 +0000] [20] [INFO] Booting worker with pid: 20
# [2024-07-27:14:33:12:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:33:12:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2024-07-27:14:33:12:INFO] Model objective : binary:logistic
# [2024-07-27:14:33:12:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:33:12:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2024-07-27:14:33:12:INFO] Model objective : binary:logistic
# [2024-07-27 14:33:10 +0000] [15] [INFO] Starting gunicorn 19.10.0
# [2024-07-27 14:33:10 +0000] [15] [INFO] Listening at: unix:/tmp/gunicorn.sock (15)
# [2024-07-27 14:33:10 +0000] [15] [INFO] Using worker: gevent
# /miniconda3/lib/python3.8/os.py:1023: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   return io.open(fd, *args, **kwargs)
# [2024-07-27 14:33:10 +0000] [19] [INFO] Booting worker with pid: 19
# [2024-07-27 14:33:10 +0000] [20] [INFO] Booting worker with pid: 20
# [2024-07-27:14:33:12:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:33:12:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2024-07-27:14:33:12:INFO] Model objective : binary:logistic
# [2024-07-27:14:33:12:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-27:14:33:12:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2024-07-27:14:33:12:INFO] Model objective : binary:logistic
# [2024-07-27:14:33:19:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:33:19 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2024-07-27:14:33:19:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:33:19 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2024-07-27:14:33:19:INFO] Determined delimiter of CSV input is ','
# /miniconda3/lib/python3.8/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# 169.254.255.130 - - [27/Jul/2024:14:33:19 +0000] "POST /invocations HTTP/1.1" 200 1089 "-" "Go-http-client/1.1"
# [2024-07-27:14:33:19:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:33:19 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2024-07-27:14:33:19:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [27/Jul/2024:14:33:19 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2024-07-27:14:33:19:INFO] Determined delimiter of CSV input is ','
# /miniconda3/lib/python3.8/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# 169.254.255.130 - - [27/Jul/2024:14:33:19 +0000] "POST /invocations HTTP/1.1" 200 1089 "-" "Go-http-client/1.1"
# 2024-07-27T14:33:19.071:[sagemaker logs]: MaxConcurrentTransforms=2, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %% [markdown]
# Let's inspect the output of the Batch Transform job in S3. It should show the list of tumors identified by their original feature columns and their corresponding probabilities of being malignant.

# %%
output_df = get_csv_output_from_s3(sm_transformer.output_path, batch_file)
output_df.head(8)
# Out:
#           0         1
# 0    843786  0.788581
# 1    851509  0.992829
# 2    852781  0.990109
# 3    855625  0.989060
# 4    857156  0.098793
# 5    858981  0.039862
# 6  85922302  0.985368
# 7    861598  0.523357

# %% [markdown]
# ## Clean up ( replace with your model name )
# Remember to delete S3 buckets and the Jupyter notebook

# %%
# Replace with your model name
model = "sagemaker-xgboost-2024-07-27-14-20-52-044"

# %%
sagemaker_client.delete_model(ModelName=model)
# Out:
# {'ResponseMetadata': {'RequestId': '5023d5b0-0470-42df-9f55-6be86877bbb1',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '5023d5b0-0470-42df-9f55-6be86877bbb1',
#    'content-type': 'application/x-amz-json-1.1',
#    'date': 'Mon, 29 Jul 2024 09:36:59 GMT',
#    'content-length': '0'},
#   'RetryAttempts': 0}}
